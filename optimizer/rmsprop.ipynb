# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import matplotlib.pyplot as plt

# %%
def get_data_loaders(batch_size=64):
    url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00291/airfoil_self_noise.dat'
    data = pd.read_csv(url, sep='\t', header=None)
    
    # Chuẩn hóa (Z-score)
    data = (data - data.mean()) / data.std()
    
    features = torch.tensor(data.iloc[:, :-1].values, dtype=torch.float32)
    labels = torch.tensor(data.iloc[:, -1].values, dtype=torch.float32).reshape(-1, 1)
    
    dataset = TensorDataset(features, labels)
    return DataLoader(dataset, batch_size, shuffle=True), features.shape[1]

def train_model(config):
    # Lấy dữ liệu
    train_iter, input_dim = get_data_loaders(config['batch_size'])
    
    # Model & Loss
    model = nn.Linear(input_dim, 1)
    loss_fn = nn.MSELoss()
    
    # Optimizer (Nơi tinh chỉnh lr và alpha(gamma))
    optimizer = torch.optim.RMSprop(
        model.parameters(), 
        lr=config['lr'], 
        alpha=config['alpha']
    )
    
    loss_history = []
    
    print(f"Bắt đầu huấn luyện: lr={config['lr']}, alpha={config['alpha']}")
    
    for epoch in range(config['epochs']):
        epoch_loss = 0
        for X, y in train_iter:
            optimizer.zero_grad()
            l = loss_fn(model(X), y)
            l.backward()
            optimizer.step()
            epoch_loss += l.item()
        
        avg_loss = epoch_loss / len(train_iter)
        loss_history.append(avg_loss)
        
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}/{config['epochs']} | Loss: {avg_loss:.4f}")
            
    return loss_history

def plot_loss(loss_history, config):
    plt.figure(figsize=(4, 3))
    plt.plot(loss_history, label=f"lr={config['lr']}, alpha={config['alpha']}")
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.grid(True)
    plt.show()

# %%
config = {
    'lr': 0.01,        # Tốc độ học
    'batch_size': 32,   # Kích thước lô
    'alpha': 0.9,
    'epochs': 20        # Số vòng lặp
}

history = train_model(config)
plot_loss(history, config)
# Out:
# Bắt đầu huấn luyện: lr=0.01, alpha=0.9
# Epoch 10/20 | Loss: 0.4887
# Epoch 20/20 | Loss: 0.4907

# %%
config = {
    'lr': 1,        # Tốc độ học
    'batch_size': 32,   # Kích thước lô
    'alpha': 0.9,
    'epochs': 20        # Số vòng lặp
}

history = train_model(config)
plot_loss(history, config)
# Out:
# Bắt đầu huấn luyện: lr=1, alpha=0.9
# Epoch 10/20 | Loss: 2.9379
# Epoch 20/20 | Loss: 2.8477
